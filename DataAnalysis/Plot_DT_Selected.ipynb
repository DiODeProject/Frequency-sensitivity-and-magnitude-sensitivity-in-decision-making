# %% [markdown]
# # This notebook produces Figs. 5, 6, 8 & 9
# (as indicated below)

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.ticker as ticker
from scipy.interpolate import griddata
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import numpy as np

# %% [markdown]
# ### import data:

# %%
choose_fcond = 1
#choose_EQcond = 'unequal' #'unequal' or 'equal'
df = pd.read_csv('../DataGenerationJune2018_constMeanMagFreq/SimDecTimeErrorRate_FreqRatio_3over2_MagRatio_4over3_FreqCondEins.csv', header=None, skiprows=1)
df[2] = df[2].fillna(15)
df[7] = df[7].fillna(15)
df = df[df[0]<10.15]
df_constRat_uneq_fc1 = df

choose_fcond = 0
choose_EQcond = 'unequal'
df = pd.read_csv('../DataGenerationJune2018_constMeanMagFreq/SimDecTimeErrorRate_FreqRatio_3over2_MagRatio_4over3_FreqCondNull.csv', header=None, skiprows=1)
df[2] = df[2].fillna(15)
df[7] = df[7].fillna(15)
df = df[df[0]<10.15]
df_constRat_uneq_fc0 = df

choose_fcond = 0
choose_EQcond = 'equal'
df = pd.read_csv('../DataGenerationJune2018_constMeanMagFreq/SimDecTimeErrorRate_FreqRatio_1_MagRatio_1_FreqCondNullEins.csv', header=None, skiprows=1)
df[2] = df[2].fillna(15)
df[7] = df[7].fillna(15)
df = df[df[0]<10.15]
df_constRat_eq_fc0 = df

# %%
choose_fcond = 1
df = pd.read_csv('../DataGenerationJune2018_constMeanMagFreq/SimDecTimeErrorRate_ConstAbsFreqAbsMag_FreqCondEins.csv', header=None, skiprows=1)
df[2] = df[2].fillna(15)
df[7] = df[7].fillna(15)
df=df[df[2]>0.01]
df=df[df[7]>0.01]
df=df[df[0]<6.0]
df=df[df[1]<6.0]
df_constMag_fc1 = df

choose_fcond = 0
df = pd.read_csv('../DataGenerationJune2018_constMeanMagFreq/SimDecTimeErrorRate_ConstAbsFreqAbsMag_FreqCondNull.csv', header=None, skiprows=1)
df[2] = df[2].fillna(15)
df[7] = df[7].fillna(15)
df=df[df[2]>0.01]
df=df[df[7]>0.01]
df=df[df[0]<6.0]
df=df[df[1]<6.0]
df_constMag_fc0 = df

# %% [markdown]
# ### Plot Fig. 5

# %%
df=None
from matplotlib.lines import Line2D

bbox_props = dict(boxstyle="round", fc="grey", ec="0.5", alpha=0.25)

figA = plt.figure(figsize=(11, 8))

nr_row = 2#3
nr_col = 3

modColor = ['dimgrey', 'r', 'k', 'b', 'g','orange']
modSymbol = ['o', 's', 'v', 'd', '>', 'x']

df=df_constMag_fc0
dfA=df[df[1]<0.34]
dfA=dfA[dfA[1]>0.33]
dfA
dfB=df[df[1]<0.67]
dfB=dfB[dfB[1]>0.66]
dfB
dfC=df[df[1]<1.01]
dfC=dfC[dfC[1]>0.99]
dfC
dfD=df[df[1]<2.08]
dfD=dfD[dfD[1]>2.07]
dfD
dfE=df[df[1]<3.01]
dfE=dfE[dfE[1]>2.99]
dfE
dfF=df[df[1]<4.01]
dfF=dfF[dfF[1]>3.99]
dfF

rhof = {'dfA': dfA[0], 'dfB': dfB[0], 'dfC': dfC[0], 'dfD': dfD[0], 'dfE': dfE[0], 'dfF': dfF[0]}
DTci = {'dfA': dfA[2], 'dfB': dfB[2], 'dfC': dfC[2], 'dfD': dfD[2], 'dfE': dfE[2], 'dfF': dfF[2]}
DTmd = {'dfA': dfA[7], 'dfB': dfB[7], 'dfC': dfC[7], 'dfD': dfD[7], 'dfE': dfE[7], 'dfF': dfF[7]}
PRci = {'dfA': dfA[4], 'dfB': dfB[4], 'dfC': dfC[4], 'dfD': dfD[4], 'dfE': dfE[4], 'dfF': dfF[4]}
PRmd = {'dfA': dfA[9], 'dfB': dfB[9], 'dfC': dfC[9], 'dfD': dfD[9], 'dfE': dfE[9], 'dfF': dfF[9]}
####################
ax1 = plt.subplot2grid((nr_row, nr_col), (0, 0), colspan=1)

counter=0
for ID in ['dfA', 'dfC', 'dfD', 'dfE']:
    ax1.plot(rhof[ID],DTci[ID], marker=modSymbol[counter], ms=13, markerfacecolor='none', markeredgewidth = 2, 
        markeredgecolor=modColor[counter], ls='solid', lw=3, markevery=2, c=modColor[counter])
    counter+=1

ax1.set_xlabel(r'$\rho_f$', fontsize=22)
ax1.text(0.65, 0.2, 'LCA', transform=ax1.transAxes, fontsize=18,
        verticalalignment='top', bbox=bbox_props)
ax1.set_title(r'(a) $\Upsilon_m=4$, $\Upsilon_f=10$ Hz', fontsize=18, y=1.02)

###################
ax2 = plt.subplot2grid((nr_row, nr_col), (1, 0), colspan=1)

counter=0
for ID in ['dfA', 'dfC', 'dfD', 'dfE']:
    ax2.plot(rhof[ID],DTmd[ID], marker=modSymbol[counter], ms=13, markerfacecolor='none', markeredgewidth = 2, 
        markeredgecolor=modColor[counter], ls='solid', lw=3, markevery=2, c=modColor[counter])
    counter+=1
ax2.set_xlabel(r'$\rho_f$', fontsize=22)
ax2.text(0.54, 0.2, 'mDDM', transform=ax2.transAxes, fontsize=18,
        verticalalignment='top', bbox=bbox_props)
ax2.set_title(r'(d) $\Upsilon_m=4$, $\Upsilon_f=10$ Hz', fontsize=18, y=1.02)

####################

df=df_constRat_eq_fc0
dfA=df[df[1]<1.01/2.]
dfA=dfA[dfA[1]>0.99/2.]
dfA
dfB=df[df[1]<2.01/2.]
dfB=dfB[dfB[1]>1.99/2.]
dfB
dfC=df[df[1]<4.01/2.]
dfC=dfC[dfC[1]>3.99/2.]
dfC
dfD=df[df[1]<6.01/2.]
dfD=dfD[dfD[1]>5.99/2.]
dfD
dfE=df[df[1]<8.01/2.]
dfE=dfE[dfE[1]>7.99/2.]
dfE
dfF=df[df[1]<10.01/2.]
dfF=dfF[dfF[1]>9.99/2.]
dfF

rhof = {'dfA': dfA[0], 'dfB': dfB[0], 'dfC': dfC[0], 'dfD': dfD[0], 'dfE': dfE[0], 'dfF': dfF[0]}
DTci = {'dfA': dfA[2], 'dfB': dfB[2], 'dfC': dfC[2], 'dfD': dfD[2], 'dfE': dfE[2], 'dfF': dfF[2]}
DTmd = {'dfA': dfA[7], 'dfB': dfB[7], 'dfC': dfC[7], 'dfD': dfD[7], 'dfE': dfE[7], 'dfF': dfF[7]}
PRci = {'dfA': dfA[4], 'dfB': dfB[4], 'dfC': dfC[4], 'dfD': dfD[4], 'dfE': dfE[4], 'dfF': dfF[4]}
PRmd = {'dfA': dfA[9], 'dfB': dfB[9], 'dfC': dfC[9], 'dfD': dfD[9], 'dfE': dfE[9], 'dfF': dfF[9]}
########################
ax3 = plt.subplot2grid((nr_row, nr_col), (0, 1), colspan=1)

counter=0
for ID in ['dfC', 'dfD', 'dfE', 'dfF']:
    ax3.plot(2*rhof[ID],DTci[ID], marker=modSymbol[counter], ms=13, markerfacecolor='none', markeredgewidth = 2, 
        markeredgecolor=modColor[counter], ls='solid', lw=3, markevery=4, c=modColor[counter])
    counter+=1
ax3.set_xlabel(r'$\Upsilon_f$ (Hz)', fontsize=22)
ax3.text(0.65, 0.2, 'LCA', transform=ax3.transAxes, fontsize=18,
        verticalalignment='top', bbox=bbox_props)
ax3.set_title(r'(b) $\rho_m=1$, $\rho_f=1$', fontsize=18, y=1.02)


###################
ax4 = plt.subplot2grid((nr_row, nr_col), (1, 1), colspan=1)

counter=0
for ID in ['dfC', 'dfD', 'dfE', 'dfF']:
    ax4.plot(2*rhof[ID],DTmd[ID], marker=modSymbol[counter], ms=13, markerfacecolor='none', markeredgewidth = 2, 
        markeredgecolor=modColor[counter], ls='solid', lw=3, markevery=4, c=modColor[counter])
    counter+=1
ax4.set_xlabel(r'$\Upsilon_f$ (Hz)', fontsize=22)
ax4.text(0.54, 0.2, 'mDDM', transform=ax4.transAxes, fontsize=18,
        verticalalignment='top', bbox=bbox_props)
ax4.set_title(r'(e) $\rho_m=1$, $\rho_f=1$', fontsize=18, y=1.02)

##################

df=df_constRat_uneq_fc0
dfA=df[df[1]<1.01/2]
dfA=dfA[dfA[1]>0.99/2]
dfA
dfB=df[df[1]<2.01/2]
dfB=dfB[dfB[1]>1.99/2]
dfB
dfC=df[df[1]<4.01/2]
dfC=dfC[dfC[1]>3.99/2]
dfC
dfD=df[df[1]<6.01/2]
dfD=dfD[dfD[1]>5.99/2]
dfD
dfE=df[df[1]<8.01/2]
dfE=dfE[dfE[1]>7.99/2]
dfE
dfF=df[df[1]<10.01/2]
dfF=dfF[dfF[1]>9.99/2]
dfF

rhof = {'dfA': dfA[0], 'dfB': dfB[0], 'dfC': dfC[0], 'dfD': dfD[0], 'dfE': dfE[0], 'dfF': dfF[0]}
DTci = {'dfA': dfA[2], 'dfB': dfB[2], 'dfC': dfC[2], 'dfD': dfD[2], 'dfE': dfE[2], 'dfF': dfF[2]}
DTmd = {'dfA': dfA[7], 'dfB': dfB[7], 'dfC': dfC[7], 'dfD': dfD[7], 'dfE': dfE[7], 'dfF': dfF[7]}
PRci = {'dfA': dfA[4], 'dfB': dfB[4], 'dfC': dfC[4], 'dfD': dfD[4], 'dfE': dfE[4], 'dfF': dfF[4]}
PRmd = {'dfA': dfA[9], 'dfB': dfB[9], 'dfC': dfC[9], 'dfD': dfD[9], 'dfE': dfE[9], 'dfF': dfF[9]}
###################
ax5 = plt.subplot2grid((nr_row, nr_col), (0, 2), colspan=1)
counter=0
for ID in ['dfC', 'dfD', 'dfE', 'dfF']:
    ax5.plot(rhof[ID]+2/3*rhof[ID],DTci[ID], marker=modSymbol[counter], ms=13, markerfacecolor='none', markeredgewidth = 2, 
        markeredgecolor=modColor[counter], ls='solid', lw=3, markevery=4, c=modColor[counter])
    counter+=1
ax5.set_xlabel(r'$\Upsilon_f$ (Hz)', fontsize=22)
ax5.text(0.65, 0.2, 'LCA', transform=ax5.transAxes, fontsize=18,
        verticalalignment='top', bbox=bbox_props)
ax5.set_title(r'(c) $\rho_m=4/3$, $\rho_f=3/2$', fontsize=18, y=1.02)


###################
ax6 = plt.subplot2grid((nr_row, nr_col), (1, 2), colspan=1)
counter=0
for ID in ['dfC', 'dfD', 'dfE', 'dfF']:
    ax6.plot(rhof[ID]+2/3*rhof[ID],DTmd[ID], marker=modSymbol[counter], ms=13, markerfacecolor='none', markeredgewidth = 2, 
        markeredgecolor=modColor[counter], ls='solid', lw=3, markevery=4, c=modColor[counter])
    counter+=1
ax6.set_xlabel(r'$\Upsilon_f$ (Hz)', fontsize=22)
ax6.text(0.54, 0.2, 'mDDM', transform=ax6.transAxes, fontsize=18,
        verticalalignment='top', bbox=bbox_props)
ax6.set_title(r'(f) $\rho_m=4/3$, $\rho_f=3/2$', fontsize=18, y=1.02)


#ax4.legend(loc='upper right', bbox_to_anchor=(0.5, 0.5), fontsize=18, handlelength=3.5, frameon=False,
#           ncol=3, shadow=False, fancybox=True)

#customise legend
legend_elements_models = [Line2D([0], [0], marker=modSymbol[0], ms=10, markerfacecolor='none', markeredgewidth = 1, 
        markeredgecolor=modColor[0], ls='solid', lw=2, c=modColor[0], label=r'$\rho_m=1/3$'),
                   Line2D([0], [0], marker=modSymbol[1], ms=10, markerfacecolor='none', markeredgewidth = 1, 
        markeredgecolor=modColor[1], ls='solid', lw=2, c=modColor[1], label=r'$\rho_m=1$'),
                   Line2D([0], [0], marker=modSymbol[2], ms=10, markerfacecolor='none', markeredgewidth = 1, 
         markeredgecolor=modColor[2], ls='solid', lw=2, c=modColor[2], label=r'$\rho_m=2$'),
                   Line2D([0], [0], marker=modSymbol[3], ms=10, markerfacecolor='none', markeredgewidth = 1, 
         markeredgecolor=modColor[3], ls='solid', lw=2, c=modColor[3], label=r'$\rho_m=3$')]
leg1 = ax1.legend(handles = legend_elements_models, loc='center left', bbox_to_anchor=(-0.12, -0.5), ncol=2, 
           shadow=False, fancybox=True, columnspacing=1, handlelength=2., fontsize=14)
#leg1.get_title().set_fontsize('16')
#leg1.get_title().set_fontweight('bold')
#leg1.get_title().set_color('k')

legend_elements_models = [Line2D([0], [0], marker=modSymbol[0], ms=10, markerfacecolor='none', markeredgewidth = 1, 
        markeredgecolor=modColor[0], ls='solid', lw=2, c=modColor[0], label=r'$\Upsilon_m=4$'),
                   Line2D([0], [0], marker=modSymbol[1], ms=10, markerfacecolor='none', markeredgewidth = 1, 
        markeredgecolor=modColor[1], ls='solid', lw=2, c=modColor[1], label=r'$\Upsilon_m=6$'),
                   Line2D([0], [0], marker=modSymbol[2], ms=10, markerfacecolor='none', markeredgewidth = 1, 
         markeredgecolor=modColor[2], ls='solid', lw=2, c=modColor[2], label=r'$\Upsilon_m=8$'),
                   Line2D([0], [0], marker=modSymbol[3], ms=10, markerfacecolor='none', markeredgewidth = 1, 
         markeredgecolor=modColor[3], ls='solid', lw=2, c=modColor[3], label=r'$\Upsilon_m=10$')]
leg2 = ax3.legend(handles = legend_elements_models, loc='center left', bbox_to_anchor=(-0.12, -0.5), ncol=2, 
           shadow=False, fancybox=True, columnspacing=1, handlelength=2., fontsize=14)

legend_elements_models = [Line2D([0], [0], marker=modSymbol[0], ms=10, markerfacecolor='none', markeredgewidth = 1, 
        markeredgecolor=modColor[0], ls='solid', lw=2, c=modColor[0], label=r'$\Upsilon_m=3.5$'),
                   Line2D([0], [0], marker=modSymbol[1], ms=10, markerfacecolor='none', markeredgewidth = 1, 
        markeredgecolor=modColor[1], ls='solid', lw=2, c=modColor[1], label=r'$\Upsilon_m=5.25$'),
                   Line2D([0], [0], marker=modSymbol[2], ms=10, markerfacecolor='none', markeredgewidth = 1, 
         markeredgecolor=modColor[2], ls='solid', lw=2, c=modColor[2], label=r'$\Upsilon_m=7$'),
                   Line2D([0], [0], marker=modSymbol[3], ms=10, markerfacecolor='none', markeredgewidth = 1, 
         markeredgecolor=modColor[3], ls='solid', lw=2, c=modColor[3], label=r'$\Upsilon_m=8.75$')]
leg3 = ax5.legend(handles = legend_elements_models, loc='center left', bbox_to_anchor=(-0.2, -0.5), ncol=2, 
           shadow=False, fancybox=True, columnspacing=1, handlelength=2., fontsize=14)


###################################
for ax in [ax1,ax2,ax3,ax4,ax5,ax6]:
    plt.setp( ax.xaxis.get_majorticklabels(), rotation=0, fontsize=18)
    plt.setp( ax.yaxis.get_majorticklabels(), rotation=0, fontsize=18)
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(2)
    ax.tick_params('both', length=8, width=2, which='major')
    ax.tick_params('both', length=6, width=1, which='minor')
    if ax == ax1:
        #ax.set_xlim(0,2)
        ax.set_ylim(0.5,2)
        ax.xaxis.set_major_locator(ticker.MultipleLocator(0.5))
        ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(0.5))
        ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
    elif ax == ax2:
        ax.set_xlim(0,2)
        ax.set_ylim(0.5,1.6)
        ax.xaxis.set_major_locator(ticker.MultipleLocator(0.5))
        ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(0.5))
        ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
    elif ax == ax3:
        ax.set_xlim(0,20)
        ax.set_ylim(0.4,2.1)
        ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
        ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(0.5))
        ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
    elif ax == ax4:
        ax.set_xlim(0,20)
        ax.set_ylim(0.2,1.8)
        ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
        ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(0.2))
        ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
    elif ax == ax5:
        ax.set_xlim(0,16)
        ax.set_ylim(0.4,2.1)
        ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
        ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(0.5))
        ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
    elif ax == ax6:
        ax.set_xlim(0,16)
        ax.set_ylim(0.2,1.8)
        ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
        ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(0.2))
        ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))


figA.subplots_adjust(hspace=0.9)
figA.subplots_adjust(wspace=0.3)
figA.subplots_adjust(bottom=0.11)
figA.subplots_adjust(top=0.92)
figA.subplots_adjust(left=0.125)
figA.subplots_adjust(right=0.96)

#figA.text(0.53, 0.02, r'response proportion option 1 $Pr(opt1)$', ha='center', fontsize=26)
figA.text(0.02, 0.5, r'mean decision time $\langle DT\rangle$ (s)', va='center', rotation='vertical', fontsize=26)


#box = ax1.get_position()
#ax1.set_position([box.x0 - box.width * 0.0 , box.y0 + box.height * 0.025,
#                 box.width * 0.95, box.height * 0.8])
#ax2.set_position([box.x0 + box.width *1.4 , box.y0 + box.height * 0.025,
#                 box.width * 0.95, box.height * 0.8]);

#fig.set_tight_layout(True)
# Out:
# <img src="data:image/png;base64,...">

# %%
#figA.savefig("Fig_DT_selected_rho_upsilon_fc0.png", dpi=150)

# %% [markdown]
# ### Plot Fig. 8

# %%
df=None
from matplotlib.lines import Line2D

bbox_props = dict(boxstyle="round", fc="grey", ec="0.5", alpha=0.25)

figB = plt.figure(figsize=(8, 8))

nr_row = 2#3
nr_col = 2

modColor = ['dimgrey', 'r', 'k', 'b', 'g','orange']
modSymbol = ['o', 's', 'v', 'd', '>', 'x']

df=df_constMag_fc1
dfA=df[df[1]<0.34]
dfA=dfA[dfA[1]>0.33]
dfA
dfB=df[df[1]<0.67]
dfB=dfB[dfB[1]>0.66]
dfB
dfC=df[df[1]<1.01]
dfC=dfC[dfC[1]>0.99]
dfC
dfD=df[df[1]<2.08]
dfD=dfD[dfD[1]>2.07]
dfD
dfE=df[df[1]<3.01]
dfE=dfE[dfE[1]>2.99]
dfE
dfF=df[df[1]<4.01]
dfF=dfF[dfF[1]>3.99]
dfF

rhof = {'dfA': dfA[0], 'dfB': dfB[0], 'dfC': dfC[0], 'dfD': dfD[0], 'dfE': dfE[0], 'dfF': dfF[0]}
DTci = {'dfA': dfA[2], 'dfB': dfB[2], 'dfC': dfC[2], 'dfD': dfD[2], 'dfE': dfE[2], 'dfF': dfF[2]}
DTmd = {'dfA': dfA[7], 'dfB': dfB[7], 'dfC': dfC[7], 'dfD': dfD[7], 'dfE': dfE[7], 'dfF': dfF[7]}
PRci = {'dfA': dfA[4], 'dfB': dfB[4], 'dfC': dfC[4], 'dfD': dfD[4], 'dfE': dfE[4], 'dfF': dfF[4]}
PRmd = {'dfA': dfA[9], 'dfB': dfB[9], 'dfC': dfC[9], 'dfD': dfD[9], 'dfE': dfE[9], 'dfF': dfF[9]}
####################
ax1 = plt.subplot2grid((nr_row, nr_col), (0, 0), colspan=1)

counter=0
for ID in ['dfA', 'dfC', 'dfD', 'dfE']:
    ax1.plot(rhof[ID],DTci[ID], marker=modSymbol[counter], ms=13, markerfacecolor='none', markeredgewidth = 2, 
        markeredgecolor=modColor[counter], ls='solid', lw=3, markevery=2, c=modColor[counter])
    counter+=1

ax1.set_xlabel(r'$\rho_f$', fontsize=22)
ax1.text(0.65, 0.87, 'LCA', transform=ax1.transAxes, fontsize=18,
        verticalalignment='top', bbox=bbox_props)
ax1.set_title(r'(a) $\Upsilon_m=4$, $\Upsilon_f=10$ Hz', fontsize=18, y=1.02)

###################
ax2 = plt.subplot2grid((nr_row, nr_col), (1, 0), colspan=1)

counter=0
for ID in ['dfA', 'dfC', 'dfD', 'dfE']:
    ax2.plot(rhof[ID],DTmd[ID], marker=modSymbol[counter], ms=13, markerfacecolor='none', markeredgewidth = 2, 
        markeredgecolor=modColor[counter], ls='solid', lw=3, markevery=2, c=modColor[counter])
    counter+=1
ax2.set_xlabel(r'$\rho_f$', fontsize=22)
ax2.text(0.54, 0.9, 'mDDM', transform=ax2.transAxes, fontsize=18,
        verticalalignment='top', bbox=bbox_props)
ax2.set_title(r'(c) $\Upsilon_m=4$, $\Upsilon_f=10$ Hz', fontsize=18, y=1.02)

####################

df=df_constRat_uneq_fc1
dfA=df[df[1]<1.01/2]
dfA=dfA[dfA[1]>0.99/2]
dfA
dfB=df[df[1]<2.01/2]
dfB=dfB[dfB[1]>1.99/2]
dfB
dfC=df[df[1]<4.01/2]
dfC=dfC[dfC[1]>3.99/2]
dfC
dfD=df[df[1]<6.01/2]
dfD=dfD[dfD[1]>5.99/2]
dfD
dfE=df[df[1]<8.01/2]
dfE=dfE[dfE[1]>7.99/2]
dfE
dfF=df[df[1]<10.01/2]
dfF=dfF[dfF[1]>9.99/2]
dfF

rhof = {'dfA': dfA[0], 'dfB': dfB[0], 'dfC': dfC[0], 'dfD': dfD[0], 'dfE': dfE[0], 'dfF': dfF[0]}
DTci = {'dfA': dfA[2], 'dfB': dfB[2], 'dfC': dfC[2], 'dfD': dfD[2], 'dfE': dfE[2], 'dfF': dfF[2]}
DTmd = {'dfA': dfA[7], 'dfB': dfB[7], 'dfC': dfC[7], 'dfD': dfD[7], 'dfE': dfE[7], 'dfF': dfF[7]}
PRci = {'dfA': dfA[4], 'dfB': dfB[4], 'dfC': dfC[4], 'dfD': dfD[4], 'dfE': dfE[4], 'dfF': dfF[4]}
PRmd = {'dfA': dfA[9], 'dfB': dfB[9], 'dfC': dfC[9], 'dfD': dfD[9], 'dfE': dfE[9], 'dfF': dfF[9]}
###################
ax3 = plt.subplot2grid((nr_row, nr_col), (0, 1), colspan=1)
counter=0
for ID in ['dfC', 'dfD', 'dfE', 'dfF']:
    ax3.plot(rhof[ID]+2/3*rhof[ID],DTci[ID], marker=modSymbol[counter], ms=13, markerfacecolor='none', markeredgewidth = 2, 
        markeredgecolor=modColor[counter], ls='solid', lw=3, markevery=4, c=modColor[counter])
    counter+=1
ax3.set_xlabel(r'$\Upsilon_f$ (Hz)', fontsize=22)
ax3.text(0.65, 0.87, 'LCA', transform=ax3.transAxes, fontsize=18,
        verticalalignment='top', bbox=bbox_props)
ax3.set_title(r'(b) $\rho_m=4/3$, $\rho_f=3/2$', fontsize=18, y=1.02)


###################
ax4 = plt.subplot2grid((nr_row, nr_col), (1, 1), colspan=1)
counter=0
for ID in ['dfC', 'dfD', 'dfE', 'dfF']:
    ax4.plot(rhof[ID]+2/3*rhof[ID],DTmd[ID], marker=modSymbol[counter], ms=13, markerfacecolor='none', markeredgewidth = 2, 
        markeredgecolor=modColor[counter], ls='solid', lw=3, markevery=4, c=modColor[counter])
    counter+=1
ax4.set_xlabel(r'$\Upsilon_f$ (Hz)', fontsize=22)
ax4.text(0.54, 0.9, 'mDDM', transform=ax4.transAxes, fontsize=18,
        verticalalignment='top', bbox=bbox_props)
ax4.set_title(r'(d) $\rho_m=4/3$, $\rho_f=3/2$', fontsize=18, y=1.02)


#ax4.legend(loc='upper right', bbox_to_anchor=(0.5, 0.5), fontsize=18, handlelength=3.5, frameon=False,
#           ncol=3, shadow=False, fancybox=True)

#customise legend
legend_elements_models = [Line2D([0], [0], marker=modSymbol[0], ms=10, markerfacecolor='none', markeredgewidth = 1, 
        markeredgecolor=modColor[0], ls='solid', lw=2, c=modColor[0], label=r'$\rho_m=1/3$'),
                   Line2D([0], [0], marker=modSymbol[1], ms=10, markerfacecolor='none', markeredgewidth = 1, 
        markeredgecolor=modColor[1], ls='solid', lw=2, c=modColor[1], label=r'$\rho_m=1$'),
                   Line2D([0], [0], marker=modSymbol[2], ms=10, markerfacecolor='none', markeredgewidth = 1, 
         markeredgecolor=modColor[2], ls='solid', lw=2, c=modColor[2], label=r'$\rho_m=2$'),
                   Line2D([0], [0], marker=modSymbol[3], ms=10, markerfacecolor='none', markeredgewidth = 1, 
         markeredgecolor=modColor[3], ls='solid', lw=2, c=modColor[3], label=r'$\rho_m=3$')]
leg1 = ax1.legend(handles = legend_elements_models, loc='center left', bbox_to_anchor=(-0.05, -0.5), ncol=2, 
           shadow=False, fancybox=True, columnspacing=1, handlelength=2., fontsize=14)
#leg1.get_title().set_fontsize('16')
#leg1.get_title().set_fontweight('bold')
#leg1.get_title().set_color('k')

legend_elements_models = [Line2D([0], [0], marker=modSymbol[0], ms=10, markerfacecolor='none', markeredgewidth = 1, 
        markeredgecolor=modColor[0], ls='solid', lw=2, c=modColor[0], label=r'$\Upsilon_m=3.5$'),
                   Line2D([0], [0], marker=modSymbol[1], ms=10, markerfacecolor='none', markeredgewidth = 1, 
        markeredgecolor=modColor[1], ls='solid', lw=2, c=modColor[1], label=r'$\Upsilon_m=5.25$'),
                   Line2D([0], [0], marker=modSymbol[2], ms=10, markerfacecolor='none', markeredgewidth = 1, 
         markeredgecolor=modColor[2], ls='solid', lw=2, c=modColor[2], label=r'$\Upsilon_m=7$'),
                   Line2D([0], [0], marker=modSymbol[3], ms=10, markerfacecolor='none', markeredgewidth = 1, 
         markeredgecolor=modColor[3], ls='solid', lw=2, c=modColor[3], label=r'$\Upsilon_m=8.75$')]
leg3 = ax3.legend(handles = legend_elements_models, loc='center left', bbox_to_anchor=(-0.12, -0.5), ncol=2, 
           shadow=False, fancybox=True, columnspacing=1, handlelength=2., fontsize=14)


###################################
for ax in [ax1,ax2,ax3,ax4]:
    plt.setp( ax.xaxis.get_majorticklabels(), rotation=0, fontsize=18)
    plt.setp( ax.yaxis.get_majorticklabels(), rotation=0, fontsize=18)
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(2)
    ax.tick_params('both', length=8, width=2, which='major')
    ax.tick_params('both', length=6, width=1, which='minor')
    if ax == ax1:
        ax.set_xlim(0,2)
        ax.set_ylim(0.5,4)
        ax.xaxis.set_major_locator(ticker.MultipleLocator(0.5))
        ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(0.5))
        ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
    elif ax == ax2:
        ax.set_xlim(0,2)
        ax.set_ylim(0.5,3)
        ax.xaxis.set_major_locator(ticker.MultipleLocator(0.5))
        ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(0.5))
        ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
    elif ax == ax3:
        ax.set_xlim(0,16)
        ax.set_ylim(0.4,1.5)
        ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
        ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(0.5))
        ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
    elif ax == ax4:
        ax.set_xlim(0,16)
        ax.set_ylim(0.4,1.5)
        ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
        ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(0.5))
        ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))


figB.subplots_adjust(hspace=0.9)
figB.subplots_adjust(wspace=0.3)
figB.subplots_adjust(bottom=0.11)
figB.subplots_adjust(top=0.92)
figB.subplots_adjust(left=0.15)
figB.subplots_adjust(right=0.96)

#figB.text(0.53, 0.02, r'response proportion option 1 $Pr(opt1)$', ha='center', fontsize=26)
figB.text(0.02, 0.5, r'mean decision time $\langle DT\rangle$ (s)', va='center', rotation='vertical', fontsize=26)


#box = ax1.get_position()
#ax1.set_position([box.x0 - box.width * 0.0 , box.y0 + box.height * 0.025,
#                 box.width * 0.95, box.height * 0.8])
#ax2.set_position([box.x0 + box.width *1.4 , box.y0 + box.height * 0.025,
#                 box.width * 0.95, box.height * 0.8]);

#fig.set_tight_layout(True)
# Out:
# <img src="data:image/png;base64,...">

# %%
#figB.savefig("Fig_DT_selected_rho_upsilon_fc1.png", dpi=150)

# %% [markdown]
# ### Plot Fig. 6

# %%
df=None
from matplotlib.lines import Line2D

bbox_props = dict(boxstyle="round", fc="grey", ec="0.5", alpha=0.25)

figC = plt.figure(figsize=(11, 8))

nr_row = 2#3
nr_col = 3

modColor = ['dimgrey', 'r', 'k', 'b', 'g','orange']
modSymbol = ['o', 's', 'v', 'd', '>', 'x']

df=df_constMag_fc0
dfA=df[df[1]<0.34]
dfA=dfA[dfA[1]>0.33]
dfA
dfB=df[df[1]<0.67]
dfB=dfB[dfB[1]>0.66]
dfB
dfC=df[df[1]<1.01]
dfC=dfC[dfC[1]>0.99]
dfC
dfD=df[df[1]<2.08]
dfD=dfD[dfD[1]>2.07]
dfD
dfE=df[df[1]<3.01]
dfE=dfE[dfE[1]>2.99]
dfE
dfF=df[df[1]<4.01]
dfF=dfF[dfF[1]>3.99]
dfF

rhof = {'dfA': dfA[0], 'dfB': dfB[0], 'dfC': dfC[0], 'dfD': dfD[0], 'dfE': dfE[0], 'dfF': dfF[0]}
DTci = {'dfA': dfA[2], 'dfB': dfB[2], 'dfC': dfC[2], 'dfD': dfD[2], 'dfE': dfE[2], 'dfF': dfF[2]}
DTmd = {'dfA': dfA[7], 'dfB': dfB[7], 'dfC': dfC[7], 'dfD': dfD[7], 'dfE': dfE[7], 'dfF': dfF[7]}
PRci = {'dfA': dfA[4], 'dfB': dfB[4], 'dfC': dfC[4], 'dfD': dfD[4], 'dfE': dfE[4], 'dfF': dfF[4]}
PRmd = {'dfA': dfA[9], 'dfB': dfB[9], 'dfC': dfC[9], 'dfD': dfD[9], 'dfE': dfE[9], 'dfF': dfF[9]}
####################
ax1 = plt.subplot2grid((nr_row, nr_col), (0, 0), colspan=1)

counter=0
for ID in ['dfA', 'dfC', 'dfD', 'dfE']:
    ax1.plot(rhof[ID],PRci[ID], marker=modSymbol[counter], ms=13, markerfacecolor='none', markeredgewidth = 2, 
        markeredgecolor=modColor[counter], ls='solid', lw=3, markevery=2, c=modColor[counter])
    counter+=1

ax1.set_xlabel(r'$\rho_f$', fontsize=22)
ax1.text(0.65, 0.32, 'LCA', transform=ax1.transAxes, fontsize=18,
        verticalalignment='top', bbox=bbox_props)
ax1.set_title(r'(a) $\Upsilon_m=4$, $\Upsilon_f=10$ Hz', fontsize=18, y=1.02)

###################
ax2 = plt.subplot2grid((nr_row, nr_col), (1, 0), colspan=1)

counter=0
for ID in ['dfA', 'dfC', 'dfD', 'dfE']:
    ax2.plot(rhof[ID],PRmd[ID], marker=modSymbol[counter], ms=13, markerfacecolor='none', markeredgewidth = 2, 
        markeredgecolor=modColor[counter], ls='solid', lw=3, markevery=2, c=modColor[counter])
    counter+=1
ax2.set_xlabel(r'$\rho_f$', fontsize=22)
ax2.text(0.54, 0.36, 'mDDM', transform=ax2.transAxes, fontsize=18,
        verticalalignment='top', bbox=bbox_props)
ax2.set_title(r'(d) $\Upsilon_m=4$, $\Upsilon_f=10$ Hz', fontsize=18, y=1.02)

####################

df=df_constRat_eq_fc0
dfA=df[df[1]<1.01/2.]
dfA=dfA[dfA[1]>0.99/2.]
dfA
dfB=df[df[1]<2.01/2.]
dfB=dfB[dfB[1]>1.99/2.]
dfB
dfC=df[df[1]<4.01/2.]
dfC=dfC[dfC[1]>3.99/2.]
dfC
dfD=df[df[1]<6.01/2.]
dfD=dfD[dfD[1]>5.99/2.]
dfD
dfE=df[df[1]<8.01/2.]
dfE=dfE[dfE[1]>7.99/2.]
dfE
dfF=df[df[1]<10.01/2.]
dfF=dfF[dfF[1]>9.99/2.]
dfF

rhof = {'dfA': dfA[0], 'dfB': dfB[0], 'dfC': dfC[0], 'dfD': dfD[0], 'dfE': dfE[0], 'dfF': dfF[0]}
DTci = {'dfA': dfA[2], 'dfB': dfB[2], 'dfC': dfC[2], 'dfD': dfD[2], 'dfE': dfE[2], 'dfF': dfF[2]}
DTmd = {'dfA': dfA[7], 'dfB': dfB[7], 'dfC': dfC[7], 'dfD': dfD[7], 'dfE': dfE[7], 'dfF': dfF[7]}
PRci = {'dfA': dfA[4], 'dfB': dfB[4], 'dfC': dfC[4], 'dfD': dfD[4], 'dfE': dfE[4], 'dfF': dfF[4]}
PRmd = {'dfA': dfA[9], 'dfB': dfB[9], 'dfC': dfC[9], 'dfD': dfD[9], 'dfE': dfE[9], 'dfF': dfF[9]}
########################
ax3 = plt.subplot2grid((nr_row, nr_col), (0, 1), colspan=1)

counter=0
for ID in ['dfC', 'dfD', 'dfE', 'dfF']:
    ax3.plot(2*rhof[ID],PRci[ID], marker=modSymbol[counter], ms=13, markerfacecolor='none', markeredgewidth = 2, 
        markeredgecolor=modColor[counter], ls='solid', lw=3, markevery=4, c=modColor[counter])
    counter+=1
ax3.set_xlabel(r'$\Upsilon_f$ (Hz)', fontsize=22)
ax3.text(0.65, 0.32, 'LCA', transform=ax3.transAxes, fontsize=18,
        verticalalignment='top', bbox=bbox_props)
ax3.set_title(r'(b) $\rho_m=1$, $\rho_f=1$', fontsize=18, y=1.02)


###################
ax4 = plt.subplot2grid((nr_row, nr_col), (1, 1), colspan=1)

counter=0
for ID in ['dfC', 'dfD', 'dfE', 'dfF']:
    ax4.plot(2*rhof[ID],PRmd[ID], marker=modSymbol[counter], ms=13, markerfacecolor='none', markeredgewidth = 2, 
        markeredgecolor=modColor[counter], ls='solid', lw=3, markevery=4, c=modColor[counter])
    counter+=1
ax4.set_xlabel(r'$\Upsilon_f$ (Hz)', fontsize=22)
ax4.text(0.54, 0.36, 'mDDM', transform=ax4.transAxes, fontsize=18,
        verticalalignment='top', bbox=bbox_props)
ax4.set_title(r'(e) $\rho_m=1$, $\rho_f=1$', fontsize=18, y=1.02)

##################

df=df_constRat_uneq_fc0
dfA=df[df[1]<1.01/2]
dfA=dfA[dfA[1]>0.99/2]
dfA
dfB=df[df[1]<2.01/2]
dfB=dfB[dfB[1]>1.99/2]
dfB
dfC=df[df[1]<4.01/2]
dfC=dfC[dfC[1]>3.99/2]
dfC
dfD=df[df[1]<6.01/2]
dfD=dfD[dfD[1]>5.99/2]
dfD
dfE=df[df[1]<8.01/2]
dfE=dfE[dfE[1]>7.99/2]
dfE
dfF=df[df[1]<10.01/2]
dfF=dfF[dfF[1]>9.99/2]
dfF

rhof = {'dfA': dfA[0], 'dfB': dfB[0], 'dfC': dfC[0], 'dfD': dfD[0], 'dfE': dfE[0], 'dfF': dfF[0]}
DTci = {'dfA': dfA[2], 'dfB': dfB[2], 'dfC': dfC[2], 'dfD': dfD[2], 'dfE': dfE[2], 'dfF': dfF[2]}
DTmd = {'dfA': dfA[7], 'dfB': dfB[7], 'dfC': dfC[7], 'dfD': dfD[7], 'dfE': dfE[7], 'dfF': dfF[7]}
PRci = {'dfA': dfA[4], 'dfB': dfB[4], 'dfC': dfC[4], 'dfD': dfD[4], 'dfE': dfE[4], 'dfF': dfF[4]}
PRmd = {'dfA': dfA[9], 'dfB': dfB[9], 'dfC': dfC[9], 'dfD': dfD[9], 'dfE': dfE[9], 'dfF': dfF[9]}
###################
ax5 = plt.subplot2grid((nr_row, nr_col), (0, 2), colspan=1)
counter=0
for ID in ['dfC', 'dfD', 'dfE', 'dfF']:
    ax5.plot(rhof[ID]+2/3*rhof[ID],PRci[ID], marker=modSymbol[counter], ms=13, markerfacecolor='none', markeredgewidth = 2, 
        markeredgecolor=modColor[counter], ls='solid', lw=3, markevery=4, c=modColor[counter])
    counter+=1
ax5.set_xlabel(r'$\Upsilon_f$ (Hz)', fontsize=22)
ax5.text(0.65, 0.32, 'LCA', transform=ax5.transAxes, fontsize=18,
        verticalalignment='top', bbox=bbox_props)
ax5.set_title(r'(c) $\rho_m=4/3$, $\rho_f=3/2$', fontsize=18, y=1.02)


###################
ax6 = plt.subplot2grid((nr_row, nr_col), (1, 2), colspan=1)
counter=0
for ID in ['dfC', 'dfD', 'dfE', 'dfF']:
    ax6.plot(rhof[ID]+2/3*rhof[ID],PRmd[ID], marker=modSymbol[counter], ms=13, markerfacecolor='none', markeredgewidth = 2, 
        markeredgecolor=modColor[counter], ls='solid', lw=3, markevery=4, c=modColor[counter])
    counter+=1
ax6.set_xlabel(r'$\Upsilon_f$ (Hz)', fontsize=22)
ax6.text(0.54, 0.36, 'mDDM', transform=ax6.transAxes, fontsize=18,
        verticalalignment='top', bbox=bbox_props)
ax6.set_title(r'(f) $\rho_m=4/3$, $\rho_f=3/2$', fontsize=18, y=1.02)


#ax4.legend(loc='upper right', bbox_to_anchor=(0.5, 0.5), fontsize=18, handlelength=3.5, frameon=False,
#           ncol=3, shadow=False, fancybox=True)

#customise legend
legend_elements_models = [Line2D([0], [0], marker=modSymbol[0], ms=10, markerfacecolor='none', markeredgewidth = 1, 
        markeredgecolor=modColor[0], ls='solid', lw=2, c=modColor[0], label=r'$\rho_m=1/3$'),
                   Line2D([0], [0], marker=modSymbol[1], ms=10, markerfacecolor='none', markeredgewidth = 1, 
        markeredgecolor=modColor[1], ls='solid', lw=2, c=modColor[1], label=r'$\rho_m=1$'),
                   Line2D([0], [0], marker=modSymbol[2], ms=10, markerfacecolor='none', markeredgewidth = 1, 
         markeredgecolor=modColor[2], ls='solid', lw=2, c=modColor[2], label=r'$\rho_m=2$'),
                   Line2D([0], [0], marker=modSymbol[3], ms=10, markerfacecolor='none', markeredgewidth = 1, 
         markeredgecolor=modColor[3], ls='solid', lw=2, c=modColor[3], label=r'$\rho_m=3$')]
leg1 = ax1.legend(handles = legend_elements_models, loc='center left', bbox_to_anchor=(-0.12, -0.5), ncol=2, 
           shadow=False, fancybox=True, columnspacing=1, handlelength=2., fontsize=14)
#leg1.get_title().set_fontsize('16')
#leg1.get_title().set_fontweight('bold')
#leg1.get_title().set_color('k')

legend_elements_models = [Line2D([0], [0], marker=modSymbol[0], ms=10, markerfacecolor='none', markeredgewidth = 1, 
        markeredgecolor=modColor[0], ls='solid', lw=2, c=modColor[0], label=r'$\Upsilon_m=4$'),
                   Line2D([0], [0], marker=modSymbol[1], ms=10, markerfacecolor='none', markeredgewidth = 1, 
        markeredgecolor=modColor[1], ls='solid', lw=2, c=modColor[1], label=r'$\Upsilon_m=6$'),
                   Line2D([0], [0], marker=modSymbol[2], ms=10, markerfacecolor='none', markeredgewidth = 1, 
         markeredgecolor=modColor[2], ls='solid', lw=2, c=modColor[2], label=r'$\Upsilon_m=8$'),
                   Line2D([0], [0], marker=modSymbol[3], ms=10, markerfacecolor='none', markeredgewidth = 1, 
         markeredgecolor=modColor[3], ls='solid', lw=2, c=modColor[3], label=r'$\Upsilon_m=10$')]
leg2 = ax3.legend(handles = legend_elements_models, loc='center left', bbox_to_anchor=(-0.12, -0.5), ncol=2, 
           shadow=False, fancybox=True, columnspacing=1, handlelength=2., fontsize=14)

legend_elements_models = [Line2D([0], [0], marker=modSymbol[0], ms=10, markerfacecolor='none', markeredgewidth = 1, 
        markeredgecolor=modColor[0], ls='solid', lw=2, c=modColor[0], label=r'$\Upsilon_m=3.5$'),
                   Line2D([0], [0], marker=modSymbol[1], ms=10, markerfacecolor='none', markeredgewidth = 1, 
        markeredgecolor=modColor[1], ls='solid', lw=2, c=modColor[1], label=r'$\Upsilon_m=5.25$'),
                   Line2D([0], [0], marker=modSymbol[2], ms=10, markerfacecolor='none', markeredgewidth = 1, 
         markeredgecolor=modColor[2], ls='solid', lw=2, c=modColor[2], label=r'$\Upsilon_m=7$'),
                   Line2D([0], [0], marker=modSymbol[3], ms=10, markerfacecolor='none', markeredgewidth = 1, 
         markeredgecolor=modColor[3], ls='solid', lw=2, c=modColor[3], label=r'$\Upsilon_m=8.75$')]
leg3 = ax5.legend(handles = legend_elements_models, loc='center left', bbox_to_anchor=(-0.2, -0.5), ncol=2, 
           shadow=False, fancybox=True, columnspacing=1, handlelength=2., fontsize=14)


###################################
for ax in [ax1,ax2,ax3,ax4,ax5,ax6]:
    plt.setp( ax.xaxis.get_majorticklabels(), rotation=0, fontsize=18)
    plt.setp( ax.yaxis.get_majorticklabels(), rotation=0, fontsize=18)
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(2)
    ax.tick_params('both', length=8, width=2, which='major')
    ax.tick_params('both', length=6, width=1, which='minor')
    if ax == ax1:
        ax.set_xlim(0,2)
        ax.set_ylim(0,1)
        ax.xaxis.set_major_locator(ticker.MultipleLocator(0.5))
        ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(0.2))
        ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
    elif ax == ax2:
        ax.set_xlim(0,2)
        ax.set_ylim(0,1)
        ax.xaxis.set_major_locator(ticker.MultipleLocator(0.5))
        ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(0.2))
        ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
    elif ax == ax3:
        ax.set_xlim(0,20)
        ax.set_ylim(0,1)
        ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
        ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(0.2))
        ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
    elif ax == ax4:
        ax.set_xlim(0,20)
        ax.set_ylim(0,1)
        ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
        ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(0.2))
        ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
    elif ax == ax5:
        ax.set_xlim(0,16)
        ax.set_ylim(0,1)
        ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
        ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(0.2))
        ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
    elif ax == ax6:
        ax.set_xlim(0,16)
        ax.set_ylim(0,1)
        ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
        ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(0.2))
        ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))


figC.subplots_adjust(hspace=0.9)
figC.subplots_adjust(wspace=0.3)
figC.subplots_adjust(bottom=0.11)
figC.subplots_adjust(top=0.92)
figC.subplots_adjust(left=0.125)
figC.subplots_adjust(right=0.96)

#figC.text(0.53, 0.02, r'response proportion option 1 $Pr(opt1)$', ha='center', fontsize=26)
figC.text(0.02, 0.5, r'probability option 1 $Pr(opt1)$', va='center', rotation='vertical', fontsize=26)


#box = ax1.get_position()
#ax1.set_position([box.x0 - box.width * 0.0 , box.y0 + box.height * 0.025,
#                 box.width * 0.95, box.height * 0.8])
#ax2.set_position([box.x0 + box.width *1.4 , box.y0 + box.height * 0.025,
#                 box.width * 0.95, box.height * 0.8]);

#fig.set_tight_layout(True)
# Out:
# <img src="data:image/png;base64,...">

# %%
#figC.savefig("Fig_PR_selected_rho_upsilon_fc0.png", dpi=150)

# %% [markdown]
# ### Plot Fig. 9

# %%
df=None
from matplotlib.lines import Line2D

bbox_props = dict(boxstyle="round", fc="grey", ec="0.5", alpha=0.25)

figD = plt.figure(figsize=(8, 8))

nr_row = 2#3
nr_col = 2

modColor = ['dimgrey', 'r', 'k', 'b', 'g','orange']
modSymbol = ['o', 's', 'v', 'd', '>', 'x']

df=df_constMag_fc1
dfA=df[df[1]<0.34]
dfA=dfA[dfA[1]>0.33]
dfA
dfB=df[df[1]<0.67]
dfB=dfB[dfB[1]>0.66]
dfB
dfC=df[df[1]<1.01]
dfC=dfC[dfC[1]>0.99]
dfC
dfD=df[df[1]<2.08]
dfD=dfD[dfD[1]>2.07]
dfD
dfE=df[df[1]<3.01]
dfE=dfE[dfE[1]>2.99]
dfE
dfF=df[df[1]<4.01]
dfF=dfF[dfF[1]>3.99]
dfF

rhof = {'dfA': dfA[0], 'dfB': dfB[0], 'dfC': dfC[0], 'dfD': dfD[0], 'dfE': dfE[0], 'dfF': dfF[0]}
DTci = {'dfA': dfA[2], 'dfB': dfB[2], 'dfC': dfC[2], 'dfD': dfD[2], 'dfE': dfE[2], 'dfF': dfF[2]}
DTmd = {'dfA': dfA[7], 'dfB': dfB[7], 'dfC': dfC[7], 'dfD': dfD[7], 'dfE': dfE[7], 'dfF': dfF[7]}
PRci = {'dfA': dfA[4], 'dfB': dfB[4], 'dfC': dfC[4], 'dfD': dfD[4], 'dfE': dfE[4], 'dfF': dfF[4]}
PRmd = {'dfA': dfA[9], 'dfB': dfB[9], 'dfC': dfC[9], 'dfD': dfD[9], 'dfE': dfE[9], 'dfF': dfF[9]}
####################
ax1 = plt.subplot2grid((nr_row, nr_col), (0, 0), colspan=1)

counter=0
for ID in ['dfA', 'dfC', 'dfD', 'dfE']:
    ax1.plot(rhof[ID],PRci[ID], marker=modSymbol[counter], ms=13, markerfacecolor='none', markeredgewidth = 2, 
        markeredgecolor=modColor[counter], ls='solid', lw=3, markevery=2, c=modColor[counter])
    counter+=1

ax1.set_xlabel(r'$\rho_f$', fontsize=22)
ax1.text(0.65, 0.5, 'LCA', transform=ax1.transAxes, fontsize=18,
        verticalalignment='top', bbox=bbox_props)
ax1.set_title(r'(a) $\Upsilon_m=4$, $\Upsilon_f=10$ Hz', fontsize=18, y=1.02)

###################
ax2 = plt.subplot2grid((nr_row, nr_col), (1, 0), colspan=1)

counter=0
for ID in ['dfA', 'dfC', 'dfD', 'dfE']:
    ax2.plot(rhof[ID],PRmd[ID], marker=modSymbol[counter], ms=13, markerfacecolor='none', markeredgewidth = 2, 
        markeredgecolor=modColor[counter], ls='solid', lw=3, markevery=2, c=modColor[counter])
    counter+=1
ax2.set_xlabel(r'$\rho_f$', fontsize=22)
ax2.text(0.6, 0.5, 'mDDM', transform=ax2.transAxes, fontsize=18,
        verticalalignment='top', bbox=bbox_props)
ax2.set_title(r'(c) $\Upsilon_m=4$, $\Upsilon_f=10$ Hz', fontsize=18, y=1.02)

####################

df=df_constRat_uneq_fc1
dfA=df[df[1]<1.01/2]
dfA=dfA[dfA[1]>0.99/2]
dfA
dfB=df[df[1]<2.01/2]
dfB=dfB[dfB[1]>1.99/2]
dfB
dfC=df[df[1]<4.01/2]
dfC=dfC[dfC[1]>3.99/2]
dfC
dfD=df[df[1]<6.01/2]
dfD=dfD[dfD[1]>5.99/2]
dfD
dfE=df[df[1]<8.01/2]
dfE=dfE[dfE[1]>7.99/2]
dfE
dfF=df[df[1]<10.01/2]
dfF=dfF[dfF[1]>9.99/2]
dfF

rhof = {'dfA': dfA[0], 'dfB': dfB[0], 'dfC': dfC[0], 'dfD': dfD[0], 'dfE': dfE[0], 'dfF': dfF[0]}
DTci = {'dfA': dfA[2], 'dfB': dfB[2], 'dfC': dfC[2], 'dfD': dfD[2], 'dfE': dfE[2], 'dfF': dfF[2]}
DTmd = {'dfA': dfA[7], 'dfB': dfB[7], 'dfC': dfC[7], 'dfD': dfD[7], 'dfE': dfE[7], 'dfF': dfF[7]}
PRci = {'dfA': dfA[4], 'dfB': dfB[4], 'dfC': dfC[4], 'dfD': dfD[4], 'dfE': dfE[4], 'dfF': dfF[4]}
PRmd = {'dfA': dfA[9], 'dfB': dfB[9], 'dfC': dfC[9], 'dfD': dfD[9], 'dfE': dfE[9], 'dfF': dfF[9]}
###################
ax3 = plt.subplot2grid((nr_row, nr_col), (0, 1), colspan=1)
counter=0
for ID in ['dfC', 'dfD', 'dfE', 'dfF']:
    ax3.plot(rhof[ID]+2/3*rhof[ID],PRci[ID], marker=modSymbol[counter], ms=13, markerfacecolor='none', markeredgewidth = 2, 
        markeredgecolor=modColor[counter], ls='solid', lw=3, markevery=4, c=modColor[counter])
    counter+=1
ax3.set_xlabel(r'$\Upsilon_f$ (Hz)', fontsize=22)
ax3.text(0.65, 0.5, 'LCA', transform=ax3.transAxes, fontsize=18,
        verticalalignment='top', bbox=bbox_props)
ax3.set_title(r'(b) $\rho_m=4/3$, $\rho_f=3/2$', fontsize=18, y=1.02)


###################
ax4 = plt.subplot2grid((nr_row, nr_col), (1, 1), colspan=1)
counter=0
for ID in ['dfC', 'dfD', 'dfE', 'dfF']:
    ax4.plot(rhof[ID]+2/3*rhof[ID],PRmd[ID], marker=modSymbol[counter], ms=13, markerfacecolor='none', markeredgewidth = 2, 
        markeredgecolor=modColor[counter], ls='solid', lw=3, markevery=4, c=modColor[counter])
    counter+=1
ax4.set_xlabel(r'$\Upsilon_f$ (Hz)', fontsize=22)
ax4.text(0.6, 0.5, 'mDDM', transform=ax4.transAxes, fontsize=18,
        verticalalignment='top', bbox=bbox_props)
ax4.set_title(r'(d) $\rho_m=4/3$, $\rho_f=3/2$', fontsize=18, y=1.02)


#ax4.legend(loc='upper right', bbox_to_anchor=(0.5, 0.5), fontsize=18, handlelength=3.5, frameon=False,
#           ncol=3, shadow=False, fancybox=True)

#customise legend
legend_elements_models = [Line2D([0], [0], marker=modSymbol[0], ms=10, markerfacecolor='none', markeredgewidth = 1, 
        markeredgecolor=modColor[0], ls='solid', lw=2, c=modColor[0], label=r'$\rho_m=1/3$'),
                   Line2D([0], [0], marker=modSymbol[1], ms=10, markerfacecolor='none', markeredgewidth = 1, 
        markeredgecolor=modColor[1], ls='solid', lw=2, c=modColor[1], label=r'$\rho_m=1$'),
                   Line2D([0], [0], marker=modSymbol[2], ms=10, markerfacecolor='none', markeredgewidth = 1, 
         markeredgecolor=modColor[2], ls='solid', lw=2, c=modColor[2], label=r'$\rho_m=2$'),
                   Line2D([0], [0], marker=modSymbol[3], ms=10, markerfacecolor='none', markeredgewidth = 1, 
         markeredgecolor=modColor[3], ls='solid', lw=2, c=modColor[3], label=r'$\rho_m=3$')]
leg1 = ax1.legend(handles = legend_elements_models, loc='center left', bbox_to_anchor=(-0.05, -0.5), ncol=2, 
           shadow=False, fancybox=True, columnspacing=1, handlelength=2., fontsize=14)
#leg1.get_title().set_fontsize('16')
#leg1.get_title().set_fontweight('bold')
#leg1.get_title().set_color('k')

legend_elements_models = [Line2D([0], [0], marker=modSymbol[0], ms=10, markerfacecolor='none', markeredgewidth = 1, 
        markeredgecolor=modColor[0], ls='solid', lw=2, c=modColor[0], label=r'$\Upsilon_m=3.5$'),
                   Line2D([0], [0], marker=modSymbol[1], ms=10, markerfacecolor='none', markeredgewidth = 1, 
        markeredgecolor=modColor[1], ls='solid', lw=2, c=modColor[1], label=r'$\Upsilon_m=5.25$'),
                   Line2D([0], [0], marker=modSymbol[2], ms=10, markerfacecolor='none', markeredgewidth = 1, 
         markeredgecolor=modColor[2], ls='solid', lw=2, c=modColor[2], label=r'$\Upsilon_m=7$'),
                   Line2D([0], [0], marker=modSymbol[3], ms=10, markerfacecolor='none', markeredgewidth = 1, 
         markeredgecolor=modColor[3], ls='solid', lw=2, c=modColor[3], label=r'$\Upsilon_m=8.75$')]
leg3 = ax3.legend(handles = legend_elements_models, loc='center left', bbox_to_anchor=(-0.12, -0.5), ncol=2, 
           shadow=False, fancybox=True, columnspacing=1, handlelength=2., fontsize=14)


###################################
for ax in [ax1,ax2,ax3,ax4]:
    plt.setp( ax.xaxis.get_majorticklabels(), rotation=0, fontsize=18)
    plt.setp( ax.yaxis.get_majorticklabels(), rotation=0, fontsize=18)
    for axis in ['top','bottom','left','right']:
        ax.spines[axis].set_linewidth(2)
    ax.tick_params('both', length=8, width=2, which='major')
    ax.tick_params('both', length=6, width=1, which='minor')
    if ax == ax1:
        ax.set_xlim(0,2)
        ax.set_ylim(0,1)
        ax.xaxis.set_major_locator(ticker.MultipleLocator(0.5))
        ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(0.2))
        ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
    elif ax == ax2:
        ax.set_xlim(0,2)
        ax.set_ylim(0,1)
        ax.xaxis.set_major_locator(ticker.MultipleLocator(0.5))
        ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(0.2))
        ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
    elif ax == ax3:
        ax.set_xlim(0,16)
        ax.set_ylim(0,1)
        ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
        ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(0.2))
        ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
    elif ax == ax4:
        ax.set_xlim(0,16)
        ax.set_ylim(0,1)
        ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
        ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(0.2))
        ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))


figD.subplots_adjust(hspace=0.9)
figD.subplots_adjust(wspace=0.3)
figD.subplots_adjust(bottom=0.11)
figD.subplots_adjust(top=0.92)
figD.subplots_adjust(left=0.15)
figD.subplots_adjust(right=0.96)

#figD.text(0.53, 0.02, r'response proportion option 1 $Pr(opt1)$', ha='center', fontsize=26)
figD.text(0.02, 0.5, r'probability option 1 $Pr(opt1)$', va='center', rotation='vertical', fontsize=26)
# Out:
# <img src="data:image/png;base64,...">

# %%
#figD.savefig("Fig_PR_selected_rho_upsilon_fc1.png", dpi=150)
